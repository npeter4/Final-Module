# %% [markdown]
# <a href="https://colab.research.google.com/github/npeter4/Final-Module/blob/main/FinalModule.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
df = pd.read_csv('nba_team_stats_00_to_23.csv')
df['season team'] = df['Team'] + ' ' + df['season']
df = df.drop(columns=['Team', 'season'])
df_new = df[['win_percentage', 'points', 'field_goal_percentage', 'three_point_percentage', 'free_throw_percentage','offensive_rebounds','defensive_rebounds','assists','plus_minus']]

inertia_values = []

for k in range(2, 31):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df_new)
    inertia_values.append(kmeans.inertia_)

plt.figure(figsize=(15, 6))
plt.plot(range(2, 31), inertia_values, marker='o')
plt.title('K-Means Inertia (Elbow Method)')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.grid(True)
plt.show()

# %%
kmeans = KMeans(n_clusters=5, random_state=42)
df['Cluster'] = kmeans.fit_predict(df_new)

# %%
cluster_0_team = df[df['Cluster'] == 0]
top_20_cluster_0 = cluster_0_team.head(20)
print(top_20_cluster_0[['season team', 'win_percentage', 'points', 'field_goal_percentage', 'three_point_percentage', 'free_throw_percentage','offensive_rebounds','defensive_rebounds','assists','plus_minus','Cluster']])
# Out:
#                         season team  win_percentage  points  \
# 26        Charlotte Hornets 2023-24           0.256    8740
# 27   Portland Trail Blazers 2023-24           0.256    8722
# 84   Portland Trail Blazers 2021-22           0.329    8711
# 86    Oklahoma City Thunder 2021-22           0.293    8506
# 87          Detroit Pistons 2021-22           0.280    8596
# 88            Orlando Magic 2021-22           0.268    8547
# 112        Sacramento Kings 2020-21           0.431    8189
# 114  Minnesota Timberwolves 2020-21           0.319    8073
# 115     Cleveland Cavaliers 2020-21           0.306    7476
# 116   Oklahoma City Thunder 2020-21           0.306    7560
# 117           Orlando Magic 2020-21           0.292    7488
# 118         Detroit Pistons 2020-21           0.278    7676
# 119         Houston Rockets 2020-21           0.236    7833
# 142      Washington Wizards 2019-20           0.347    8238
# 146           Atlanta Hawks 2019-20           0.299    7488
# ...

# %%
cluster_1_team = df[df['Cluster'] == 1]
top_20_cluster_1 = cluster_1_team.head(20)
print(top_20_cluster_1[['season team', 'win_percentage', 'points', 'field_goal_percentage', 'three_point_percentage', 'free_throw_percentage','offensive_rebounds','defensive_rebounds','assists','plus_minus','Cluster']])
# Out:
#                         season team  win_percentage  points  \
# 23        Memphis Grizzlies 2023-24           0.329    8677
# 64         Dallas Mavericks 2021-22           0.634    8858
# 74      Cleveland Cavaliers 2021-22           0.537    8839
# 78          New York Knicks 2021-22           0.451    8731
# 90                Utah Jazz 2020-21           0.722    8382
# 91             Phoenix Suns 2020-21           0.708    8300
# 92       Philadelphia 76ers 2020-21           0.681    8182
# 93            Brooklyn Nets 2020-21           0.667    8537
# 94           Denver Nuggets 2020-21           0.653    8284
# 95              LA Clippers 2020-21           0.653    8209
# 96          Milwaukee Bucks 2020-21           0.639    8649
# 99   Portland Trail Blazers 2020-21           0.583    8360
# 103   Golden State Warriors 2020-21           0.542    8187
# 106          Indiana Pacers 2020-21           0.472    8302
# 107      Washington Wizards 2020-21           0.472    8398
# ...

# %%
cluster_2_team = df[df['Cluster'] == 2]
top_20_cluster_2 = cluster_2_team.head(20)
print(top_20_cluster_2[['season team', 'win_percentage', 'points', 'field_goal_percentage', 'three_point_percentage', 'free_throw_percentage','offensive_rebounds','defensive_rebounds','assists','plus_minus','Cluster']])
# Out:
#                        season team  win_percentage  points  \
# 0           Boston Celtics 2023-24           0.780    9887
# 1           Denver Nuggets 2023-24           0.695    9418
# 2    Oklahoma City Thunder 2023-24           0.695    9847
# 3   Minnesota Timberwolves 2023-24           0.683    9264
# 4              LA Clippers 2023-24           0.622    9481
# 5         Dallas Mavericks 2023-24           0.610    9664
# 6          New York Knicks 2023-24           0.610    9249
# 7          Milwaukee Bucks 2023-24           0.598    9756
# 8     New Orleans Pelicans 2023-24           0.598    9436
# 9             Phoenix Suns 2023-24           0.598    9532
# 10     Cleveland Cavaliers 2023-24           0.585    9236
# 11          Indiana Pacers 2023-24           0.573   10110
# 12      Los Angeles Lakers 2023-24           0.573    9679
# 13           Orlando Magic 2023-24           0.573    9058
# 14      Philadelphia 76ers 2023-24           0.573    9397
# ...

# %%
cluster_3_team = df[df['Cluster'] == 3]
top_20_cluster_3 = cluster_3_team.head(20)
print(top_20_cluster_3[['season team', 'win_percentage', 'points', 'field_goal_percentage', 'three_point_percentage', 'free_throw_percentage','offensive_rebounds','defensive_rebounds','assists','plus_minus','Cluster']])
# Out:
#                         season team  win_percentage  points  \
# 141       Charlotte Hornets 2019-20           0.354    6687
# 143           Chicago Bulls 2019-20           0.338    6945
# 144         New York Knicks 2019-20           0.318    6983
# 145         Detroit Pistons 2019-20           0.303    7078
# 147  Minnesota Timberwolves 2019-20           0.297    7248
# 148     Cleveland Cavaliers 2019-20           0.292    6948
# 149   Golden State Warriors 2019-20           0.231    6912
# 360           Chicago Bulls 2011-12           0.758    6359
# 361       San Antonio Spurs 2011-12           0.758    6841
# 362   Oklahoma City Thunder 2011-12           0.712    6802
# 363              Miami Heat 2011-12           0.697    6500
# 364          Indiana Pacers 2011-12           0.636    6449
# 365      Los Angeles Lakers 2011-12           0.621    6422
# 366       Memphis Grizzlies 2011-12           0.621    6269
# 367           Atlanta Hawks 2011-12           0.606    6375
# ...

# %%
cluster_4_team = df[df['Cluster'] == 4]
top_20_cluster_4 = cluster_4_team.head(20)
print(top_20_cluster_4[['season team', 'win_percentage', 'points', 'field_goal_percentage', 'three_point_percentage', 'free_throw_percentage','offensive_rebounds','defensive_rebounds','assists','plus_minus','Cluster']])
# Out:
#                        season team  win_percentage  points  \
# 97        Dallas Mavericks 2020-21           0.583    8096
# 98      Los Angeles Lakers 2020-21           0.583    7887
# 100          Atlanta Hawks 2020-21           0.569    8186
# 101        New York Knicks 2020-21           0.569    7706
# 102             Miami Heat 2020-21           0.556    7781
# 104      Memphis Grizzlies 2020-21           0.528    8157
# 105         Boston Celtics 2020-21           0.500    8109
# 108      Charlotte Hornets 2020-21           0.458    7881
# 109      San Antonio Spurs 2020-21           0.458    7998
# 110          Chicago Bulls 2020-21           0.431    7969
# 113        Toronto Raptors 2020-21           0.375    8011
# 121        Toronto Raptors 2019-20           0.736    8118
# 122     Los Angeles Lakers 2019-20           0.732    8054
# 125         Denver Nuggets 2019-20           0.630    8124
# 126         Indiana Pacers 2019-20           0.616    7989
# ...
